# %%
import gymnasium as gym
import JSSEnv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import gymnasium as gym
# ----> 2 import JSSEnv
#
# ModuleNotFoundError: No module named 'JSSEnv'
